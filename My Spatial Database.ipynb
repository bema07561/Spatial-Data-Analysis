# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, box
from rtree import index
import time
import re
import folium
from folium.plugins import MarkerCluster
import warnings
warnings.filterwarnings("ignore")

# %%
class SpatialDatabase:
    def __init__(self, file_path):
        self.file_path = file_path
        self.gdf = self.read_csv_and_convert_to_geodataframe(file_path)
        self.spatial_index = self.build_spatial_index()

    def build_spatial_index(self):
        idx = index.Index()
        for i, geom in enumerate(self.gdf.geometry):
            idx.insert(i, geom.bounds)
        return idx

    def read_csv_and_convert_to_geodataframe(self, file_path):
        df = pd.read_csv(file_path, encoding='utf-8')
        geometry = [Point(xy) for xy in zip(df['wgs_lng'], df['wgs_lat'])]
        gdf = gpd.GeoDataFrame(df, geometry=geometry, crs='EPSG:4326')
        return gdf

    def nearest_neighbor_query(self, query_point, type_regex_str):
        # Filter points by type_code
        filtered_points = self.gdf[self.gdf['type_code'].astype(str).str.match(type_regex_str)]

        if filtered_points.empty:
            return "No matching POI found with the specified type_code."

        # Find nearest point among filtered points
        nearest_idx = filtered_points.geometry.distance(query_point).idxmin()
        nearest_poi = self.gdf.loc[[nearest_idx]].copy()
        nearest_poi['type_code'] = nearest_poi['type_code'].astype(str)

        return nearest_poi

    def range_query(self, query_range, type_regex_str):
        min_lng, min_lat, max_lng, max_lat = query_range  # Unpack the query range
        query_area = box(min_lng, min_lat, max_lng, max_lat)  # Construct the query area
        possible_matches_index = list(self.spatial_index.intersection(query_area.bounds))
        possible_matches = self.gdf.iloc[possible_matches_index].copy()
        possible_matches['type_code'] = possible_matches['type_code'].astype(str)
        result = possible_matches[possible_matches['type_code'].str.contains(type_regex_str)]
        return result


    def brute_force_range_query(self, query_range, type_regex_str):
        query_area = box(*query_range)
        result = self.gdf[
            (self.gdf['wgs_lng'] >= query_area.bounds[0]) &
            (self.gdf['wgs_lng'] <= query_area.bounds[2]) &
            (self.gdf['wgs_lat'] >= query_area.bounds[1]) &
            (self.gdf['wgs_lat'] <= query_area.bounds[3])
        ].copy()

        result['type_code'] = result['type_code'].astype(str)
        result = result[result['type_code'].str.contains(type_regex_str)]
        return result

    def brute_force_nearest_neighbor_query(self, query_point, type_regex_str):
        nearest_poi = self.gdf.iloc[self.gdf.geometry.distance(query_point).idxmin()]
        if nearest_poi['type_code'].startswith(type_regex_str):
            return nearest_poi
        else:
            return None

# %%
def plot_map(initial_point, found_points):
    # Create a map centered at the initial point
    map_center = [initial_point.y, initial_point.x]
    m = folium.Map(location=map_center, zoom_start=15)

    # Add marker for initial point
    folium.Marker(
        location=[initial_point.y, initial_point.x],
        popup='Initial POI',
        icon=folium.Icon(color='blue')
    ).add_to(m)

    # Add markers for found ATMs
    marker_cluster = MarkerCluster().add_to(m)
    for idx, row in found_points.iterrows():
        folium.Marker(
            location=[row.geometry.y, row.geometry.x],
            popup=f"Type Code: {row['type_code']}",
            icon=folium.Icon(color='green')
        ).add_to(marker_cluster)

    return m

# %%
file_path = 'Assignment2-2012_BIT_POI.csv'
data = SpatialDatabase(file_path)

# %%
def measure_execution_time(func, *args):
    start_time = time.time()
    result = func(*args)
    end_time = time.time()
    execution_time = end_time - start_time
    return result, execution_time

# %%
query_point = Point(116.310, 39.955)
radius = 1000  # in meters
query_area = query_point.buffer(radius / 111000)  # Convert meters to degrees (approximately)
type_regex_str = "^5"
result_index, time_index = measure_execution_time(data.range_query, query_area.bounds, type_regex_str)
result_scan, time_scan = measure_execution_time(data.brute_force_range_query, query_area.bounds, type_regex_str)

print("Execution time with spatial index:", time_index)
print("Execution time without spatial index (Brute-force):", time_scan)
# Out:
# Execution time with spatial index: 0.004369020462036133
# Execution time without spatial index (Brute-force): 0.001964569091796875

# %%
df = pd.read_csv('Assignment2-2012_BIT_POI.csv')
df.head()
# Out:
#            name    wgs_lat     wgs_lng  type_code base_type sub_type category
# 0      寰太大厦员工餐厅  39.958029  116.317624      50100      餐饮服务      中餐厅      中餐厅
# 1  一手店（北三环西路辅路）  39.965707  116.313841      50000      餐饮服务   餐饮相关场所     餐饮相关
# 2         三博冒菜馆  39.966749  116.317380      50100      餐饮服务      中餐厅      中餐厅
# 3          奇豆の恋  39.967321  116.318733      50700      餐饮服务      冷饮店      冷饮店
# 4           茶真乡  39.953802  116.316822      50400      餐饮服务   休闲餐饮场所   休闲餐饮场所

# %%
query_point = Point(116.311, 39.958)
type_regex_str = "^1603"
width = 0.01
height = 0.01

# Calculate the minimum and maximum longitude and latitude values
min_lng = query_point.x - (width / 2)
max_lng = query_point.x + (width / 2)
min_lat = query_point.y - (height / 2)
max_lat = query_point.y + (height / 2)

# Create the query_range tuple
query_range = (min_lng, min_lat, max_lng, max_lat)

# Pass the individual values of query_range to the box() function
query_area = box(query_range[0], query_range[1], query_range[2], query_range[3])

# Now you can use query_area in your range_query method
range_atm = data.range_query(query_area.bounds, type_regex_str)
range_atm
# Out:
#                         name    wgs_lat     wgs_lng type_code base_type  \
# 1157      中国工商银行ＡＴＭ（理工大学储蓄所）  39.959395  116.309544    160302    金融保险服务
# 1091          交通银行ＡＴＭ（放光社区西）  39.962941  116.308857    160305    金融保险服务
# 1136  中国工商银行２４小时自助银行（魏公村储蓄所）  39.953313  116.312723    160302    金融保险服务
# 1158         交通银行ＡＴＭ（韦伯豪家园北）  39.953381  116.313634    160305    金融保险服务
# 1172                 中国银行ＡＴＭ  39.953308  116.309591    160301    金融保险服务
# 1160         北京银行ＡＴＭ（魏公村南区北）  39.953308  116.309591    160316    金融保险服务
# 1159   中国光大银行ＡＴＭ（北京外国语大学社区北）  39.954074  116.306761    160310    金融保险服务
# 1170   中国工商银行ＡＴＭ（北京外国语大学社区北）  39.954157  116.306760    160302    金融保险服务
# 1120      招商银行ＡＴＭ（魏公村路８号院东北）  39.956512  116.310542    160306    金融保险服务
#
#      sub_type   category                    geometry
# 1157    自动提款机  中国工商银行ATM  POINT (116.30954 39.95939)
# 1091    自动提款机    交通银行ATM  POINT (116.30886 39.96294)
# 1136    自动提款机  中国工商银行ATM  POINT (116.31272 39.95331)
# 1158    自动提款机    交通银行ATM  POINT (116.31363 39.95338)
# 1172    自动提款机    中国银行ATM  POINT (116.30959 39.95331)
# 1160    自动提款机    北京银行ATM  POINT (116.30959 39.95331)
# 1159    自动提款机  中国光大银行ATM  POINT (116.30676 39.95407)
# 1170    自动提款机  中国工商银行ATM  POINT (116.30676 39.95416)
# 1120    自动提款机    招商银行ATM  POINT (116.31054 39.95651)

# %%
nearest_atm = data.nearest_neighbor_query(query_point, type_regex_str)

print("Nearest ATM (type_code starting with '1603XX'):")
print(nearest_atm)
# Out:
# Nearest ATM (type_code starting with '1603XX'):
#                     name    wgs_lat     wgs_lng type_code base_type sub_type  \
# 1120  招商银行ＡＴＭ（魏公村路８号院东北）  39.956512  116.310542    160306    金融保险服务    自动提款机
#
#      category                    geometry
# 1120  招商银行ATM  POINT (116.31054 39.95651)

# %%
map_with_points = plot_map(query_point, nearest_atm)
map_with_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_190d2b232ce02a4892c1f4b45a1625c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_190d2b232ce02a4892c1f4b45a1625c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_190d2b232ce02a4892c1f4b45a1625c3 = L.map(
#                 &quot;map_190d2b232ce02a4892c1f4b45a1625c3&quot;,
#                 {
#                     center: [39.958, 116.311],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b991d802edd0900e21cffd6863bca41f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b991d802edd0900e21cffd6863bca41f.addTo(map_190d2b232ce02a4892c1f4b45a1625c3);
#
#
#             var marker_c996c7e2c4e49e2d6011eee45699e7c3 = L.marker(
#                 [39.958, 116.311],
#                 {}
#             ).addTo(map_190d2b232ce02a4892c1f4b45a1625c3);
#
#
#             var icon_99b7cbcdd1e7479fb5cda4cc15255c92 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c996c7e2c4e49e2d6011eee45699e7c3.setIcon(icon_99b7cbcdd1e7479fb5cda4cc15255c92);
#
#
#         var popup_cb370bb311fa2257a501b250e153cdc7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eaf5e0468d2e26496783e1740c30388a = $(`&lt;div id=&quot;html_eaf5e0468d2e26496783e1740c30388a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Initial POI&lt;/div&gt;`)[0];
#                 popup_cb370bb311fa2257a501b250e153cdc7.setContent(html_eaf5e0468d2e26496783e1740c30388a);
#
#
#
#         marker_c996c7e2c4e49e2d6011eee45699e7c3.bindPopup(popup_cb370bb311fa2257a501b250e153cdc7)
#         ;
#
#
#
#
#             var marker_cluster_952263b6c718b159b140bc849e0ec0b9 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_0dde5eaaf1729e75849258a6091493c5 = L.marker(
#                 [39.9565121976451, 116.31054154116],
#                 {}
#             ).addTo(marker_cluster_952263b6c718b159b140bc849e0ec0b9);
#
#
#             var icon_7d0ad88a8fe1c19c0b061644a99fdaef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0dde5eaaf1729e75849258a6091493c5.setIcon(icon_7d0ad88a8fe1c19c0b061644a99fdaef);
#
#
#         var popup_31ea4d337666cca7fa65a43fdfab2500 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a28abd855fd6e001b7ff9b283b568a84 = $(`&lt;div id=&quot;html_a28abd855fd6e001b7ff9b283b568a84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Type Code: 160306&lt;/div&gt;`)[0];
#                 popup_31ea4d337666cca7fa65a43fdfab2500.setContent(html_a28abd855fd6e001b7ff9b283b568a84);
#
#
#
#         marker_0dde5eaaf1729e75849258a6091493c5.bindPopup(popup_31ea4d337666cca7fa65a43fdfab2500)
#         ;
#
#
#
#
#             marker_cluster_952263b6c718b159b140bc849e0ec0b9.addTo(map_190d2b232ce02a4892c1f4b45a1625c3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
type_regex_str = "^1702"
range_office = data.range_query(query_area.bounds, type_regex_str)
range_office.head()
# Out:
#                        name    wgs_lat     wgs_lng type_code base_type  \
# 534            北京海涛艺术装饰设计中心  39.961997  116.310869    170201      公司企业
# 558         德丰杰龙脉创业投资咨询有限公司  39.959594  116.315862    170200      公司企业
# 851  北京广视通达网络技术有限公司（海淀科技大厦）  39.959594  116.315862    170206      公司企业
# 541          北京科技风险投资股份有限公司  39.959594  116.315862    170200      公司企业
# 433  中海纪元数字技术发展有限公司（海淀科技大厦）  39.959594  116.315862    170206      公司企业
#
#     sub_type category                    geometry
# 534       公司     广告装饰  POINT (116.31087 39.96200)
# 558       公司       公司  POINT (116.31586 39.95959)
# 851       公司     网络科技  POINT (116.31586 39.95959)
# 541       公司       公司  POINT (116.31586 39.95959)
# 433       公司     网络科技  POINT (116.31586 39.95959)

# %%
nearest_office = data.nearest_neighbor_query(query_point, type_regex_str)

print("Nearest office (type_code starting with '1203XX'):")
print(nearest_office)
# Out:
# Nearest office (type_code starting with '1203XX'):
#              name    wgs_lat     wgs_lng type_code base_type sub_type  \
# 534  北京海涛艺术装饰设计中心  39.961997  116.310869    170201      公司企业       公司
#
#     category                    geometry
# 534     广告装饰  POINT (116.31087 39.96200)

# %%
map_with_points = plot_map(query_point, nearest_office)
map_with_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_273190d64a3320d9775da1635fb91ceb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_273190d64a3320d9775da1635fb91ceb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_273190d64a3320d9775da1635fb91ceb = L.map(
#                 &quot;map_273190d64a3320d9775da1635fb91ceb&quot;,
#                 {
#                     center: [39.958, 116.311],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d00630a88b38a4f010533deec1841156 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d00630a88b38a4f010533deec1841156.addTo(map_273190d64a3320d9775da1635fb91ceb);
#
#
#             var marker_a7b57bc4d346fedd7fe36f2ddd512768 = L.marker(
#                 [39.958, 116.311],
#                 {}
#             ).addTo(map_273190d64a3320d9775da1635fb91ceb);
#
#
#             var icon_9979ea5d55ba5c3c54a0163a034adc9b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a7b57bc4d346fedd7fe36f2ddd512768.setIcon(icon_9979ea5d55ba5c3c54a0163a034adc9b);
#
#
#         var popup_86a1507241cc9a4de1d1e8cbf6a8bd23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8dd0db48a6f8dc11c987fd3db0d102e = $(`&lt;div id=&quot;html_d8dd0db48a6f8dc11c987fd3db0d102e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Initial POI&lt;/div&gt;`)[0];
#                 popup_86a1507241cc9a4de1d1e8cbf6a8bd23.setContent(html_d8dd0db48a6f8dc11c987fd3db0d102e);
#
#
#
#         marker_a7b57bc4d346fedd7fe36f2ddd512768.bindPopup(popup_86a1507241cc9a4de1d1e8cbf6a8bd23)
#         ;
#
#
#
#
#             var marker_cluster_93f556d91527bc145223baeaf0fa7077 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_0d29b7132fad3904752140e165687493 = L.marker(
#                 [39.961997366244, 116.310869122607],
#                 {}
#             ).addTo(marker_cluster_93f556d91527bc145223baeaf0fa7077);
#
#
#             var icon_a9cab37dda8315a054c3cb9a77c249d6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0d29b7132fad3904752140e165687493.setIcon(icon_a9cab37dda8315a054c3cb9a77c249d6);
#
#
#         var popup_71b9f9e8ac1fc38e97fca46d8dacf28d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eeff7fb5ce05b44859533f0ef78d46af = $(`&lt;div id=&quot;html_eeff7fb5ce05b44859533f0ef78d46af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Type Code: 170201&lt;/div&gt;`)[0];
#                 popup_71b9f9e8ac1fc38e97fca46d8dacf28d.setContent(html_eeff7fb5ce05b44859533f0ef78d46af);
#
#
#
#         marker_0d29b7132fad3904752140e165687493.bindPopup(popup_71b9f9e8ac1fc38e97fca46d8dacf28d)
#         ;
#
#
#
#
#             marker_cluster_93f556d91527bc145223baeaf0fa7077.addTo(map_273190d64a3320d9775da1635fb91ceb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
query_point = Point(116.310, 39.955)

buffer_radius = 500 
query_area = query_point.buffer(buffer_radius / 111000)  # Convert meters to degrees (approximately)

type_regex_str = "^5"

result = data.range_query(query_area.bounds, type_regex_str)

num_restaurants = result[result['type_code'].str.startswith('5')].shape[0]

print("Number of restaurants (type_code starting with '5XXXX') within 500 meters:")
print(num_restaurants)
# Out:
# Number of restaurants (type_code starting with '5XXXX') within 500 meters:
# 40

# %%
map_with_restaurants = plot_map(query_point, result)
map_with_restaurants
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e5acfd11bf11710c122e82bd0aade24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e5acfd11bf11710c122e82bd0aade24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e5acfd11bf11710c122e82bd0aade24 = L.map(
#                 &quot;map_3e5acfd11bf11710c122e82bd0aade24&quot;,
#                 {
#                     center: [39.955, 116.31],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9fc4ac1c63a1314d0599dfb35b590f8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d9fc4ac1c63a1314d0599dfb35b590f8.addTo(map_3e5acfd11bf11710c122e82bd0aade24);
#
#
#             var marker_312cc86ef95be8e5961d7ee36d02a918 = L.marker(
#                 [39.955, 116.31],
#                 {}
#             ).addTo(map_3e5acfd11bf11710c122e82bd0aade24);
#
#
#             var icon_03bd70c9af1a5ec24d15e383c232fa87 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_312cc86ef95be8e5961d7ee36d02a918.setIcon(icon_03bd70c9af1a5ec24d15e383c232fa87);
#
#
#         var popup_7d2c48f6ed3c6d49166ede09a42fa7a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5c3c079069e75ade3439965e6408266 = $(`&lt;div id=&quot;html_c5c3c079069e75ade3439965e6408266&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Initial POI&lt;/div&gt;`)[0];
#                 popup_7d2c48f6ed3c6d49166ede09a42fa7a5.setContent(html_c5c3c079069e75ade3439965e6408266);
#
#
#
#         marker_312cc86ef95be8e5961d7ee36d02a918.bindPopup(popup_7d2c48f6ed3c6d49166ede09a42fa7a5)
#         ;
#
#
#
#
#             var marker_cluster_82ed9ba01e111476638c2d9dc002daed = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_4473b23824770997eb0fda5b041c04b1 = L.marker(
#                 [39.9558974774689, 116.312532178574],
#                 {}
#             ).addTo(marker_cluster_82ed9ba01e111476638c2d9dc002daed);
#
#
#             var icon_3fee30803fe1bf4136be861049e9dc6d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4473b23824770997eb0fda5b041c04b1.setIcon(icon_3fee30803fe1bf4136be861049e9dc6d);
#
#
#         var popup_6f40543297649122de55c17df3e2447a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_61fdf482dd4ebfbfeeddb1f548cb8448 = $(`&lt;div id=&quot;html_61fdf482dd4ebfbfeeddb1f548cb8448&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Type Code: 50500&lt;/div&gt;`)[0];
#                 popup_6f40543297649122de55c17df3e2447a.setContent(html_61fdf482dd4ebfbfeeddb1f548cb8448);
#
#
#
#         marker_4473b23824770997eb0fda5b041c04b1.bindPopup(popup_6f40543297649122de55c17df3e2447a)
#         ;
#
#
#
#
#             var marker_791cdab3804315404ae43d456e93b36b = L.marker(
#                 [39.9559018183109, 116.312351582772],
#                 {}
#             ).addTo(marker_cluster_82ed9ba01e111476638c2d9dc002daed);
#
#
#             var icon_e83af4e7fd24704c25640cf0095cb0df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_791cdab3804315404ae43d456e93b36b.setIcon(icon_e83af4e7fd24704c25640cf0095cb0df);
#
#
#         var popup_108cbd0cdae24afdbd7e5b7f2c2fe18d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_346ada1a172884bbb24046628332a8a6 = $(`&lt;div id=&quot;html_346ada1a172884bbb24046628332a8a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Type Code: 50500&lt;/div&gt;`)[0];
#                 popup_108cbd0cdae24afdbd7e5b7f2c2fe18d.setContent(html_346
